# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle

# %%
direc = '02_GPU_Analy_rand_seed-7_ML_epochs-1000_KL_epochs-1000_learning_rate-0.0001_MLweight-1.0_KLweight-1.0_explore1.0_temperature-1.0_s_time-2020-01-16_18_47_39.339824'
file = 'ML_only_losses_dict'
losses = pickle.load( open( '../pytorch/experiments/'+direc+'/'+file+'.pickle', 'rb') )

# %%
plt.plot(losses)
plt.ylim([-30,50])
# Out:
# (-30, 50)
